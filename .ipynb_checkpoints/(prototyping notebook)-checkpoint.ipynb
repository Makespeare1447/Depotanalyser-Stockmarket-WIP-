# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
colors = ['#845EC2', '#D65DB1', '#FF6F91', '#FF9671', '#FFC75F', '#F9F871', '#5EADC2', '#4AC2C6', '#54D6BB',
          '#7FE6A4', '#B8F288', '#F9F871', '#282F44', '#453A49', '#6D3B47', '#FFD8BE', '#FFEEDD']

# %%
#functions:

def df_setup():
    df = pd.read_excel('depot.xls', encoding='latin1')
    df = df.drop(labels=['ISIN', 'in %' , 'Börse', 'Zeit', 'Unnamed: 22', 'Unnamed: 6', 'Unnamed: 4',
                    'Unnamed: 12', 'Unnamed: 14', '+/- Vortag', 'Unnamed: 16', 'Sperre/Lagerst.',
                    'Unnamed: 18', 'Unnamed: 24', 'Datum', 'Unnamed: 20'], axis=1)
    df = df.rename(columns={"Bezeichnung": "Position", "Stk./Nominale": "Shares", 'Aktueller Wert': 'Total Value', 
                       'Akt. Kurs': 'Value per Share', 'Einstandswert' : 'Past Value', 'Entwicklung abs.':'Absolute Change', 'Entwicklung in %':'Relative Change',
                           'Einstandskurs':'Past Value per Share', 'Kategorie':'Category'})
    df.sort_values("Total Value", axis = 0, ascending = False, 
                   inplace = True, na_position ='last')
    df = df.reset_index(drop=True)
    
    for i in range(df.shape[0]):           #cut down namelenght
        if len(df['Position'][i])>15:
            df['Position'][i] = df['Position'][i][0:14]
        else:
            pass
    return df

def getdate():
    datestring = time.strftime("%d.%m.%Y")
    return datestring

# %%
df = df_setup()
# Out:
# C:\Users\Marco\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Barplot:

labels = df['Position']
value = df['Total Value']
change_abs = df['Absolute Change']
change_rel = df['Relative Change']

#colors:
changecolor = []
for i in change_rel:
    if i>0:
        changecolor.append('green')
    elif i<0: 
        changecolor.append('red')
    else: 
        changecolor.append('white')
        
barplotsize = (13,8)
barcount = len(labels)
xpos = np.arange(barcount)
barwidth = (barplotsize[0]/barcount)/3.5


#plot:
fig = plt.figure(figsize=barplotsize)
ax1 = fig.add_subplot(1,1,1)
ax1.bar(xpos-barwidth/2, value, edgecolor='black', color=colors, width=barwidth)
ax1.bar(xpos+barwidth/2, change_abs, edgecolor='black', color=changecolor, width=barwidth)
ax1.set_xticks(xpos)
ax1.set_xticklabels(labels, rotation='vertical')
ax1.grid()
#ax1.set_facecolor('lightgray')




#annotation:
xposi=0
for i in range(len(df['Absolute Change'])):
    if df['Relative Change'][xposi]<0:
        yposi = 15
        color = 'red'
    elif df['Relative Change'][xposi]>0:
        yposi = df['Absolute Change'][i]+15
        color = 'green'
    else:
        yposi = 15
        color = 'black'
        
    ax1.annotate(xy=(xposi+barwidth/10, yposi),s=str(round(df['Relative Change'][xposi],2)), rotation=0, color=color)
    xposi=xposi+1

# %%
#PiePlot:
barplotsize = (8,8)
labels = df['Position']
value = df['Total Value']

fig = plt.figure(figsize=barplotsize)
ax2 = fig.add_subplot(1,1,1)
ax2.pie(value, labels=labels, shadow=True, autopct='%1.1f%%', startangle=140, colors=colors, rotatelabels=True )
circle = plt.Circle((0,0),0.7,fc='white')
ax2.add_artist(circle)

# %%
#PiePlot  2:
barplotsize = (8,8)
labels = df['Category']
value = df['Total Value']

fig = plt.figure(figsize=barplotsize)
ax3 = fig.add_subplot(1,1,1)
ax3.pie(value, labels=labels, shadow=True, autopct='%1.1f%%', startangle=140, colors=colors, rotatelabels=True )
circle = plt.Circle((0,0),0.7,fc='white')
ax3.add_artist(circle)

# %%
df.head()
# Out:
#          Position Category    Shares  Past Value per Share  Value per Share  \
# 0  TESLA INC. DL    Aktien  4.000000            226.977500          230.100
# 1      APPLE INC.   Aktien  3.000000            155.140000          183.780
# 2  JOHNSON + JOHN   Aktien  3.000000            123.860000          114.300
# 3  BOEING CO.       Aktien  1.000000            313.450000          332.650
# 4  X(IE)-MSCI EM.    Fonds  7.419444             43.867168           43.816
#
#    Total Value  Past Value  Absolute Change  Relative Change
# 0   920.400000      907.91        12.490000         1.375687
# 1   551.340000      465.42        85.920000        18.460745
# 2   342.900000      371.58       -28.680000        -7.718392
# 3   332.650000      313.45        19.200000         6.125379
# 4   325.090358      325.47        -0.379642        -0.116644
